# %% [markdown]
# Seaborn exercises

# %% [markdown]
# Explore the relationships between the number of gears a car has and its combined MPG rating. Visualize these two dimensions using scatter plot, lmplot, jointplot, boxplot and swarmplot. What conclusions can you draw?

# %% [markdown]
# first, we get the data from the internet

# %%
import pandas as pd
df=pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")
df.head()
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8

# %% [markdown]
# Finding the most common # of gears

# %%
gear_counts=df['# Gears'].value_counts()
gear_counts.plot(kind='bar')

# %%
import matplotlib.pyplot as plt
plt.pie(gear_counts)
# Out:
# ([<matplotlib.patches.Wedge at 0x100956b0>,
# ...
#  [Text(0.43536036887681623, 1.010178869909405, ''),
#   Text(-1.0848302001200893, -0.18205339026617118, ''),
#   Text(0.06253553841774939, -1.0982209734087227, ''),
#   Text(0.7795172145302924, -0.7761139814814151, ''),
#   Text(1.008264278963492, -0.43977624283973094, ''),
#   Text(1.0748150148244884, -0.23403564666057822, ''),
#   Text(1.0973055083640542, -0.07694557371223572, '')])

# %% [markdown]
# Next is to import Seaborn and create the scatter plot

# %%
import seaborn as sns
sns.scatterplot(x="# Gears",y="CombMPG",data=df)

# %% [markdown]
# a few makes with one and six gears have stand out fuel efficiency

# %%
sns.lmplot(x='# Gears', y="CombMPG", data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-6ca05299c95b> in <module>
# ----> 1 sns.lmplot(x='# Gears', y="CombMPG", data=df)
#
# c:\users\allen.t\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     615         scatter_kws=scatter_kws, line_kws=line_kws,
#     616         )
# --> 617     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     618
#     619     # Add a legend
#
# ...

# %%
sns.jointplot(x="# Gears",y="CombMPG",data=df)

# %%
sns.boxplot(x="# Gears",y="CombMPG",data=df)

# %% [markdown]
# We are able to see that a single gear car is quite efficient with a median of around 33 MPG

# %%
sns.swarmplot(x="# Gears",y="CombMPG",data=df)
